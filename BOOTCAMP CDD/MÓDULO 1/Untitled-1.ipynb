# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lam = 3
data = np.random.exponential(1/lam, 300)
plt.hist(data)
# Out:
# (array([159.,  75.,  32.,  12.,  12.,   1.,   3.,   2.,   3.,   1.]),
#  array([7.67796808e-04, 2.56353608e-01, 5.11939419e-01, 7.67525230e-01,
#         1.02311104e+00, 1.27869685e+00, 1.53428266e+00, 1.78986847e+00,
#         2.04545428e+00, 2.30104010e+00, 2.55662591e+00]),
#  <BarContainer object of 10 artists>)

# %%
data
