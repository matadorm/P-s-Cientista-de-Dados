# %%
import requests
import json
import pandas as pd

# %%
url = 'http://api.chess.com/pub/titled/GM'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}
result = requests.get(url, headers=headers)
lista_jogadores = result.json()

# %%
result
# Out:
# <Response [200]>

# %%
# visualiza a quantidade de jogadores
len(lista_jogadores['players'])
# Out:
# 1567

# %%
lista_jogadores['players'][:10]
# Out:
# ['0blivi0usspy',
#  '123lt',
#  '124chess',
#  '1977ivan',
#  '1stsecond',
#  '4thd-alpeacefulmoon',
#  '731291',
#  'a-adly',
#  'a-fier',
#  'abasovn']

# %%
# funcao para coletar as informações dos jogadores GM

def busca_usuario(usuario):
    url = f"https://api.chess.com/pub/player/{usuario}"
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}
    response = requests.get(url, headers=headers)
    #print(response.json())
    if response.ok:
        return response.json()

# %%
# coletando os dados dos jogadores
print("Iniciando a Coleta")
lista_usuario = []
for usuario in lista_jogadores['players'][:50]:
    dados_usuario = busca_usuario(usuario)
    #print(f"Coleta Realizada com sucesso para o jogador: {usuario}")
    lista_usuario.append(dados_usuario)
print("Finalizada a Coleta")
# Out:
# Iniciando a Coleta
# Finalizada a Coleta

# %%
# Imprimindo a lista de usuarios coletada
lista_usuario[:2]
# Out:
# [{'player_id': 360558673,
#   '@id': 'https://api.chess.com/pub/player/0blivi0usspy',
#   'url': 'https://www.chess.com/member/0blivi0usspy',
#   'username': '0blivi0usspy',
#   'title': 'GM',
#   'followers': 1,
#   'country': 'https://api.chess.com/pub/country/GB',
#   'last_online': 1715799420,
#   'joined': 1714573164,
#   'status': 'premium',
#   'is_streamer': False,
#   'verified': False,
#   'league': 'Bronze',
#   'streaming_platforms': []},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/18800602.e26b721f.200x200o.e738019a328a.jpeg',
#   'player_id': 18800602,
#   '@id': 'https://api.chess.com/pub/player/123lt',
#   'url': 'https://www.chess.com/member/123lt',
#   'name': 'Tingjie Lei',
#   'username': '123lt',
#   'title': 'GM',
#   'followers': 158,
#   'country': 'https://api.chess.com/pub/country/CN',
#   'last_online': 1712610623,
#   'joined': 1410059361,
#   'status': 'premium',
#   'is_streamer': False,
#   'verified': False,
#   'league': 'Stone',
# ...

# %%
df_jogadores = pd.DataFrame(lista_usuario)
df_jogadores
# Out:
#     player_id                                                @id  \
# 0   360558673      https://api.chess.com/pub/player/0blivi0usspy
# 1    18800602             https://api.chess.com/pub/player/123lt
# 2    29499974          https://api.chess.com/pub/player/124chess
# 3    30610578          https://api.chess.com/pub/player/1977ivan
# 4    13013662         https://api.chess.com/pub/player/1stsecond
# 5    69412324  https://api.chess.com/pub/player/4thd-alpeacef...
# 6     7246509            https://api.chess.com/pub/player/731291
# 7    43349734            https://api.chess.com/pub/player/a-adly
# 8    10968500            https://api.chess.com/pub/player/a-fier
# 9    59828698           https://api.chess.com/pub/player/abasovn
# 10  205859387   https://api.chess.com/pub/player/abbasifarhassan
# 11  336295585  https://api.chess.com/pub/player/abbasovfarid1979
# 12   39633960  https://api.chess.com/pub/player/abdimalik_abd...
# ...
